# %%
import wget
url = 'https://www.dropbox.com/s/nilt43hyl1dx82k/dataset.zip?dl=0'
filename =  wget.download(url)
print(filename)
# Out:
# -1 / unknowndataset.zip

# %%
pip install tensorflow --upgrade
# Out:
# Requirement already satisfied: tensorflow in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (2.8.0)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: gast>=0.2.1 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.1.2)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages)
#     WARNING: Ignoring invalid distribution -pencv-python (c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-nightly-gpu 2.10.0.dev20220507 requires tf-estimator-nightly~=2.10.0.dev, but you have tf-estimator-nightly 2.8.0.dev2021122109 which is incompatible.
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (13.0.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (0.24.0)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Using cached tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.44.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.13.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (4.0.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (1.21.2)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: setuptools in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (60.9.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.36.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.26.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.0.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.6.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (4.11.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.25.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (3.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\dhan\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.2.0)
# Installing collected packages: tf-estimator-nightly
#   Attempting uninstall: tf-estimator-nightly
#     Found existing installation: tf-estimator-nightly 2.10.0.dev2022050708
#     Uninstalling tf-estimator-nightly-2.10.0.dev2022050708:
#       Successfully uninstalled tf-estimator-nightly-2.10.0.dev2022050708
# Successfully installed tf-estimator-nightly-2.8.0.dev2021122109

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from keras.applications.mobilenet import MobileNet, preprocess_input 
from keras.losses import categorical_crossentropy
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13220/1416806974.py in <module>
#       5 from keras.layers import Flatten, Dense
#       6 from keras.models import Model
# ----> 7 from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
#       8 from keras.applications.mobilenet import MobileNet, preprocess_input
#       9 from keras.losses import categorical_crossentropy
#
# ImportError: cannot import name 'img_to_array' from 'keras.preprocessing.image' (C:\Users\Dhan\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\preprocessing\image.py)

# %% [markdown]
# #  Building our Model To train the data

# %%
# Working with pre trained model 

base_model = MobileNet( input_shape=(224,224,3), include_top= False )

for layer in base_model.layers:
  layer.trainable = False


x = Flatten()(base_model.output)
x = Dense(units=7 , activation='softmax' )(x)

# creating our model.
model = Model(base_model.input, x)

# %%
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy']  )

# %% [markdown]
# # Preparing our data using data generator

# %%
train_datagen = ImageDataGenerator(
     zoom_range = 0.2, 
     shear_range = 0.2, 
     horizontal_flip=True, 
     rescale = 1./255
)

train_data = train_datagen.flow_from_directory(directory= "./train/", 
                                               target_size=(224,224), 
                                               batch_size=32,
                                  )


train_data.class_indices
# Out:
# Found 28709 images belonging to 7 classes.
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(directory= "./test/", 
                                           target_size=(224,224), 
                                           batch_size=32,
                                  )
# Out:
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # visualizaing the data that is fed to train data gen

# %%
# to visualize the images in the traing data denerator 

t_img , label = train_data.next()

#-----------------------------------------------------------------------------
# function when called will prot the images 
def plotImages(img_arr, label):
  """
  input  :- images array 
  output :- plots the images 
  """
  count = 0
  for im, l in zip(img_arr,label) :
    plt.imshow(im)
    plt.title(im.shape)
    plt.axis = False
    plt.show()
    
    count += 1
    if count == 10:
      break

#-----------------------------------------------------------------------------
# function call to plot the images 
plotImages(t_img, label)

# %% [markdown]
# # having early stopping and model check point

# %%
## having early stopping and model check point 

from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')

# model check point
mc = ModelCheckpoint(filepath="best_model.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list 
call_back = [es, mc]

# %%
hist = model.fit_generator(train_data, 
                           steps_per_epoch= 10, 
                           epochs= 30, 
                           validation_data=val_data,
                           validation_steps = 8,
                           callbacks=[es,mc])
# Out:
# C:\Users\Dhan\AppData\Local\Temp/ipykernel_13220/4134021615.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(train_data,
# Epoch 1/30
# 10/10 [==============================] - ETA: 0s - loss: 8.8177 - accuracy: 0.2781
# Epoch 1: val_accuracy improved from -inf to 0.35156, saving model to best_model.h5
# 10/10 [==============================] - 19s 2s/step - loss: 8.8177 - accuracy: 0.2781 - val_loss: 8.3862 - val_accuracy: 0.3516
# Epoch 2/30
# 10/10 [==============================] - ETA: 0s - loss: 7.0364 - accuracy: 0.3875
# Epoch 2: val_accuracy did not improve from 0.35156
# 10/10 [==============================] - 19s 2s/step - loss: 7.0364 - accuracy: 0.3875 - val_loss: 8.3833 - val_accuracy: 0.3281
# Epoch 3/30
# 10/10 [==============================] - ETA: 0s - loss: 6.3728 - accuracy: 0.3844
# Epoch 3: val_accuracy improved from 0.35156 to 0.35938, saving model to best_model.h5
# 10/10 [==============================] - 17s 2s/step - loss: 6.3728 - accuracy: 0.3844 - val_loss: 6.5578 - val_accuracy: 0.3594
# Epoch 4/30
# 10/10 [==============================] - ETA: 0s - loss: 5.6217 - accuracy: 0.4094
# Epoch 4: val_accuracy improved from 0.35938 to 0.41797, saving model to best_model.h5
# 10/10 [==============================] - 18s 2s/step - loss: 5.6217 - accuracy: 0.4094 - val_loss: 4.8493 - val_accuracy: 0.4180
# Epoch 5/30
# 10/10 [==============================] - ETA: 0s - loss: 5.6383 - accuracy: 0.3812
# Epoch 5: val_accuracy improved from 0.41797 to 0.48828, saving model to best_model.h5
# 10/10 [==============================] - 18s 2s/step - loss: 5.6383 - accuracy: 0.3812 - val_loss: 4.9564 - val_accuracy: 0.4883
# Epoch 6/30
# 10/10 [==============================] - ETA: 0s - loss: 6.0279 - accuracy: 0.3969
# Epoch 6: val_accuracy did not improve from 0.48828
# 10/10 [==============================] - 17s 2s/step - loss: 6.0279 - accuracy: 0.3969 - val_loss: 4.7996 - val_accuracy: 0.4414
# Epoch 7/30
# 10/10 [==============================] - ETA: 0s - loss: 6.0241 - accuracy: 0.4281
# Epoch 7: val_accuracy did not improve from 0.48828
# 10/10 [==============================] - 17s 2s/step - loss: 6.0241 - accuracy: 0.4281 - val_loss: 6.6182 - val_accuracy: 0.3359
# Epoch 8/30
# 10/10 [==============================] - ETA: 0s - loss: 5.9812 - accuracy: 0.3688
# Epoch 8: val_accuracy did not improve from 0.48828
# 10/10 [==============================] - 16s 2s/step - loss: 5.9812 - accuracy: 0.3688 - val_loss: 4.8812 - val_accuracy: 0.4297
# Epoch 9/30
# 10/10 [==============================] - ETA: 0s - loss: 4.4837 - accuracy: 0.5188
# Epoch 9: val_accuracy did not improve from 0.48828
# 10/10 [==============================] - 16s 2s/step - loss: 4.4837 - accuracy: 0.5188 - val_loss: 6.0688 - val_accuracy: 0.3516
# Epoch 10/30
# 10/10 [==============================] - ETA: 0s - loss: 6.2091 - accuracy: 0.4156
# Epoch 10: val_accuracy did not improve from 0.48828
# 10/10 [==============================] - 17s 2s/step - loss: 6.2091 - accuracy: 0.4156 - val_loss: 7.6993 - val_accuracy: 0.4141
# Epoch 10: early stopping

# %%
# Loading the best fit model 
from keras.models import load_model
model = load_model("best_model.h5")

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# just to map o/p values 
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))

# %%
# path for the image to see if it predics correct class

path = "./test/angry/PrivateTest_1054527.jpg"
img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image  
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13220/1899996973.py in <module>
#       2
#       3 path = "./test/angry/PrivateTest_1054527.jpg"
# ----> 4 img = load_img(path, target_size=(224,224) )
#       5
#       6 i = img_to_array(img)/255
#
# NameError: name 'load_img' is not defined
